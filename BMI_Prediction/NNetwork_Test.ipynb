# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# Load the processed dataset
data = pd.read_csv("processed_dataset.csv")
data.head()
# Out:
#    Gender       Age  family_history_with_overweight  FAVC      FCVC       NCP  \
# 0       0 -0.522124                               1     0 -0.785019  0.404153
# 1       0 -0.522124                               1     0  1.088342  0.404153
# 2       1 -0.206889                               1     0 -0.785019  0.404153
# 3       1  0.423582                               0     0  1.088342  0.404153
# 4       1 -0.364507                               0     0 -0.785019 -2.167023
#
#    CAEC  SMOKE      CH2O  SCC       FAF       TUE  CALC  MTRANS  NObeyesdad  \
# 0     2      0 -0.013073    0 -1.188039  0.561997     3       3           1
# 1     2      1  1.618759    1  2.339750 -1.080625     2       3           1
# 2     2      0 -0.013073    0  1.163820  0.561997     1       3           1
# 3     2      0 -0.013073    0  1.163820 -1.080625     1       4           5
# 4     2      0 -0.013073    0 -1.188039 -1.080625     2       3           6
#
#         BMI
# 0 -0.663421
# 1 -0.681937
# 2 -0.740967
# 3 -0.355619
# 4 -0.169522

# %%
# Define function to train and test neural network model
def train_and_test_nn(data, include_bmi=True):
    # Include or exclude BMI column based on input
    if not include_bmi:
        data = data.drop(columns=["BMI"])

    # Separate features and target
    X = data.drop(columns=["NObeyesdad"])
    y = data["NObeyesdad"]

    # Split into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

    # Normalize the data (optional but often helps with neural networks)
    X_train = X_train / X_train.max()
    X_test = X_test / X_test.max()

    # Build the neural network model
    model = Sequential()
    model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(7, activation='softmax'))  # 7 classes in target variable

    # Compile the model
    model.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)

    # Make predictions
    y_pred = model.predict(X_test)
    y_pred_classes = y_pred.argmax(axis=1)

    # Evaluate the model
    accuracy = accuracy_score(y_test, y_pred_classes)
    print(f"Accuracy (with{'out' if not include_bmi else ''} BMI): {accuracy:.2f}")
    print(classification_report(y_test, y_pred_classes))

    return model

# %%
# Train and test with BMI
print("Model Performance with BMI (Neural Network):")
model_with_bmi_nn = train_and_test_nn(data, include_bmi=True)
# Out:
# Model Performance with BMI (Neural Network):
# Epoch 1/30
# C:\Users\jwidc\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2678 - loss: 1.8716
# Epoch 2/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4180 - loss: 1.6083
# Epoch 3/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5344 - loss: 1.3529
# Epoch 4/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6315 - loss: 1.0818
# Epoch 5/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6730 - loss: 0.9269
# Epoch 6/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7329 - loss: 0.8531
# Epoch 7/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7562 - loss: 0.7068
# Epoch 8/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8278 - loss: 0.6006
# Epoch 9/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8547 - loss: 0.5432
# Epoch 10/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8632 - loss: 0.4910
# Epoch 11/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8940 - loss: 0.4296
# Epoch 12/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8797 - loss: 0.4146
# Epoch 13/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8911 - loss: 0.3886
# Epoch 14/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9097 - loss: 0.3599
# Epoch 15/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9115 - loss: 0.3224
# Epoch 16/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9133 - loss: 0.3102
# Epoch 17/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9338 - loss: 0.2605
# Epoch 18/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9398 - loss: 0.2443
# Epoch 19/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9484 - loss: 0.2219
# Epoch 20/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9373 - loss: 0.2254
# Epoch 21/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9437 - loss: 0.2087
# Epoch 22/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9524 - loss: 0.1878
# Epoch 23/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9544 - loss: 0.1835
# Epoch 24/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9590 - loss: 0.1756
# Epoch 25/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9508 - loss: 0.1715
# Epoch 26/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9625 - loss: 0.1525
# Epoch 27/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9612 - loss: 0.1449
# Epoch 28/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9671 - loss: 0.1366
# Epoch 29/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9725 - loss: 0.1320
# Epoch 30/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.1346
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy (with BMI): 0.92
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94        82
#            1       0.86      0.85      0.85        86
#            2       0.98      0.93      0.96       106
#            3       0.97      0.99      0.98        89
#            4       1.00      0.99      0.99        97
#            5       0.82      0.84      0.83        87
#            6       0.90      0.85      0.88        87
#
#     accuracy                           0.92       634
#    macro avg       0.92      0.92      0.92       634
# weighted avg       0.92      0.92      0.92       634

# %%
# Train and test without BMI
print("\nModel Performance without BMI (Neural Network):")
model_without_bmi_nn = train_and_test_nn(data, include_bmi=False)
# Out:
# Model Performance without BMI (Neural Network):
# Epoch 1/30
# C:\Users\jwidc\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1814 - loss: 1.9159
# Epoch 2/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3927 - loss: 1.6715
# Epoch 3/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4425 - loss: 1.4836
# Epoch 4/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4781 - loss: 1.3540
# Epoch 5/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5189 - loss: 1.2774
# Epoch 6/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5559 - loss: 1.2255
# Epoch 7/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5773 - loss: 1.1532
# Epoch 8/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5962 - loss: 1.1166
# Epoch 9/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5882 - loss: 1.0920
# Epoch 10/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6130 - loss: 1.0387
# Epoch 11/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6323 - loss: 1.0176
# Epoch 12/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6226 - loss: 0.9953
# Epoch 13/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6430 - loss: 0.9644
# Epoch 14/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6565 - loss: 0.9202
# Epoch 15/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6555 - loss: 0.9370
# Epoch 16/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6508 - loss: 0.9089
# Epoch 17/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6624 - loss: 0.8890
# Epoch 18/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6779 - loss: 0.8848
# Epoch 19/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6579 - loss: 0.8897
# Epoch 20/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6776 - loss: 0.8704
# Epoch 21/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7060 - loss: 0.8160
# Epoch 22/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6852 - loss: 0.8178
# Epoch 23/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7025 - loss: 0.8037
# Epoch 24/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7189 - loss: 0.7879
# Epoch 25/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7145 - loss: 0.7663
# Epoch 26/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7021 - loss: 0.8146
# Epoch 27/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7326 - loss: 0.7456
# Epoch 28/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7410 - loss: 0.7296
# Epoch 29/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7336 - loss: 0.7453
# Epoch 30/30
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7567 - loss: 0.7124
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy (without BMI): 0.66
#               precision    recall  f1-score   support
#
#            0       0.61      0.87      0.71        82
#            1       0.48      0.38      0.43        86
#            2       0.60      0.61      0.61       106
#            3       0.82      0.87      0.84        89
#            4       0.95      0.99      0.97        97
#            5       0.61      0.53      0.56        87
#            6       0.48      0.38      0.42        87
#
#     accuracy                           0.66       634
#    macro avg       0.65      0.66      0.65       634
# weighted avg       0.65      0.66      0.65       634
